# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !sudo cp -r -v "/content/drive/MyDrive/a/a/Pearson.IT.CCNP.Security.Cisco.Identify.Services.Engine.SISE.300.715.REPACK/" "/content/drive/Shareddrives/testhf/abs"
# Out:
# '/content/drive/MyDrive/a/a/Pearson.IT.CCNP.Security.Cisco.Identify.Services.Engine.SISE.300.715.REPACK/' -> '/content/drive/Shareddrives/testhf/abs/Pearson.IT.CCNP.Security.Cisco.Identify.Services.Engine.SISE.300.715.REPACK'
# '/content/drive/MyDrive/a/a/Pearson.IT.CCNP.Security.Cisco.Identify.Services.Engine.SISE.300.715.REPACK/035 - 3.9 Troubleshooting NAD.mp4' -> '/content/drive/Shareddrives/testhf/abs/Pearson.IT.CCNP.Security.Cisco.Identify.Services.Engine.SISE.300.715.REPACK/035 - 3.9 Troubleshooting NAD.mp4'
# cp: error reading '/content/drive/MyDrive/a/a/Pearson.IT.CCNP.Security.Cisco.Identify.Services.Engine.SISE.300.715.REPACK/035 - 3.9 Troubleshooting NAD.mp4': Input/output error
# ...
